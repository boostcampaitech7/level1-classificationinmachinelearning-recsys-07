# %% [markdown]
# # Train - xgb
#
#
# 리더보드 ACC: 0.3956

# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import torch
# import lightgbm as lgb
from xgboost import XGBClassifier

from glob import glob
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings(action='ignore')




def random_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    
    return True
random_seed(seed=42)
# Out:
# True

# %%
''' 
train_df = train_label + train_data
test_df = test_label + test_data

all_df = all_label + all_data
'''

dir_path = "/data/ephemeral/home/data"

data_path = "./data.csv"
all_df = pd.read_csv(data_path)

train_df = all_df.loc[all_df["_type"]=="train"].drop(columns=["_type"])
test_df = all_df.loc[all_df["_type"]=="test"].drop(columns=["_type"])
print("data shape: ", all_df.shape)
print("train shape: ", train_df.shape)
print("test shape: ", test_df.shape)
# Out:
# data shape:  (11552, 509)
# train shape:  (8760, 508)
# test shape:  (2792, 508)

# %%
train_df.head()
# Out:
#                     ID  target  coinbase_premium_gap  coinbase_premium_index  \
# 0  2023-01-01 00:00:00     2.0                 -9.86               -0.059650
# 1  2023-01-01 01:00:00     1.0                 -8.78               -0.053047
# 2  2023-01-01 02:00:00     1.0                 -9.59               -0.057952
# 3  2023-01-01 03:00:00     1.0                 -9.74               -0.058912
# 4  2023-01-01 04:00:00     2.0                -10.14               -0.061373
#
#    funding_rates  long_liquidations  long_liquidations_usd  \
# 0       0.005049              0.012              197.51610
# 1       0.005049              0.000                0.00000
# 2       0.005049              0.000                0.00000
# 3       0.005067              0.593             9754.76891
# 4       0.006210              0.361             5944.43714
#
#    short_liquidations  short_liquidations_usd  open_interest  ...  \
# 0               0.000                 0.00000   6.271344e+09  ...
# 1               0.712             11833.56104   6.288683e+09  ...
# 2               0.000                 0.00000   6.286796e+09  ...
# 3               0.000                 0.00000   6.284575e+09  ...
# 4               0.000                 0.00000   6.291582e+09  ...
#
#    active_count_shift_10  receiver_count_shift_10  sender_count_shift_10  \
# 0                 -999.0                   -999.0                 -999.0
# 1                 -999.0                   -999.0                 -999.0
# 2                 -999.0                   -999.0                 -999.0
# 3                 -999.0                   -999.0                 -999.0
# 4                 -999.0                   -999.0                 -999.0
#
#    liquidation_diff_shift_10  liquidation_usd_diff_shift_10  \
# 0                     -999.0                         -999.0
# 1                     -999.0                         -999.0
# 2                     -999.0                         -999.0
# 3                     -999.0                         -999.0
# 4                     -999.0                         -999.0
#
#    volume_diff_shift_10  liquidation_diffg_shift_10  \
# 0                -999.0                      -999.0
# 1                -999.0                      -999.0
# 2                -999.0                      -999.0
# 3                -999.0                      -999.0
# 4                -999.0                      -999.0
#
#    liquidation_usd_diffg_shift_10  volume_diffg_shift_10  \
# 0                          -999.0                 -999.0
# 1                          -999.0                 -999.0
# 2                          -999.0                 -999.0
# 3                          -999.0                 -999.0
# 4                          -999.0                 -999.0
#
#    buy_sell_volume_ratio_shift_10
# 0                          -999.0
# 1                          -999.0
# 2                          -999.0
# 3                          -999.0
# 4                          -999.0
#
# [5 rows x 508 columns]

# %%
test_df.head()
# Out:
#                        ID  target  coinbase_premium_gap  \
# 8760  2024-01-01 00:00:00     NaN                -22.57
# 8761  2024-01-01 01:00:00     NaN                -18.88
# 8762  2024-01-01 02:00:00     NaN                 -9.78
# 8763  2024-01-01 03:00:00     NaN                 -5.38
# 8764  2024-01-01 04:00:00     NaN                -10.22
#
#       coinbase_premium_index  funding_rates  long_liquidations  \
# 8760               -0.053137       0.042276           0.661000
# 8761               -0.044305       0.042578           0.483000
# 8762               -0.022968       0.043265           6.724000
# 8763               -0.012710       0.043927          20.107080
# 8764               -0.024104       0.045189          12.654933
#
#       long_liquidations_usd  short_liquidations  short_liquidations_usd  \
# 8760            27996.83627           17.251477            7.350195e+05
# 8761            20552.07715           36.152847            1.546929e+06
# 8762           285861.94051            1.623000            6.941107e+04
# 8763           849377.45559            0.071000            3.003284e+03
# 8764           533700.00186            1.651000            7.014376e+04
#
#       open_interest  ...  active_count_shift_10  receiver_count_shift_10  \
# 8760   1.034554e+10  ...                80380.0                  25484.0
# 8761   1.040165e+10  ...                66899.0                  17439.0
# 8762   1.039594e+10  ...                65812.0                  15247.0
# 8763   1.033749e+10  ...                41020.0                  15500.0
# 8764   1.039205e+10  ...                57263.0                  20099.0
#
#       sender_count_shift_10  liquidation_diff_shift_10  \
# 8760                58539.0                  -3.275801
# 8761                51709.0                   1.924824
# 8762                52548.0                  35.532924
# 8763                26760.0                  -0.651000
# 8764                38653.0                  -5.000800
#
#       liquidation_usd_diff_shift_10  volume_diff_shift_10  \
# 8760                  -1.393753e+05          6.311677e+07
# 8761                   8.087924e+04         -4.717319e+07
# 8762                   1.493391e+06         -6.240264e+07
# 8763                  -2.787925e+04          3.778580e+07
# 8764                  -2.122320e+05          2.343655e+07
#
#       liquidation_diffg_shift_10  liquidation_usd_diffg_shift_10  \
# 8760                        -1.0                            -1.0
# 8761                         1.0                             1.0
# 8762                         1.0                             1.0
# 8763                        -1.0                            -1.0
# 8764                        -1.0                            -1.0
#
#       volume_diffg_shift_10  buy_sell_volume_ratio_shift_10
# 8760                    1.0                        1.475138
# 8761                   -1.0                        0.701483
# 8762                   -1.0                        0.740465
# 8763                    1.0                        1.495168
# 8764                    1.0                        1.234126
#
# [5 rows x 508 columns]

# %% [markdown]
# ## Train

# %%
y = train_df['target']    # fetures
x = train_df.drop(['ID', 'target'], axis=1)    # target

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)

# Train
model = XGBClassifier(
    eval_metric='mlogloss',
    random_state=42
)
model = model.fit(
            x_train, y_train, 
            eval_set=[(x_val, y_val)]
            )

# Val
y_pred = model.predict(x_val)

accuracy = accuracy_score(y_val, y_pred)
print(f"acc: {accuracy}")
# Out:
# (7008, 506) (7008,)
# (1752, 506) (1752,)
# [0]	validation_0-mlogloss:1.30192
# [1]	validation_0-mlogloss:1.24821
# [2]	validation_0-mlogloss:1.21166
# [3]	validation_0-mlogloss:1.18589
# [4]	validation_0-mlogloss:1.17000
# [5]	validation_0-mlogloss:1.15877
# [6]	validation_0-mlogloss:1.15286
# [7]	validation_0-mlogloss:1.14883
# [8]	validation_0-mlogloss:1.14665
# [9]	validation_0-mlogloss:1.14310
# [10]	validation_0-mlogloss:1.14292
# [11]	validation_0-mlogloss:1.14097
# [12]	validation_0-mlogloss:1.14294
# [13]	validation_0-mlogloss:1.14504
# [14]	validation_0-mlogloss:1.14827
# [15]	validation_0-mlogloss:1.14929
# [16]	validation_0-mlogloss:1.15214
# [17]	validation_0-mlogloss:1.15507
# [18]	validation_0-mlogloss:1.15715
# [19]	validation_0-mlogloss:1.16119
# [20]	validation_0-mlogloss:1.16139
# [21]	validation_0-mlogloss:1.16342
# [22]	validation_0-mlogloss:1.16281
# [23]	validation_0-mlogloss:1.16580
# [24]	validation_0-mlogloss:1.16612
# [25]	validation_0-mlogloss:1.16774
# [26]	validation_0-mlogloss:1.17159
# [27]	validation_0-mlogloss:1.17332
# [28]	validation_0-mlogloss:1.17670
# [29]	validation_0-mlogloss:1.17905
# [30]	validation_0-mlogloss:1.18009
# [31]	validation_0-mlogloss:1.18214
# [32]	validation_0-mlogloss:1.18436
# [33]	validation_0-mlogloss:1.18505
# [34]	validation_0-mlogloss:1.18702
# [35]	validation_0-mlogloss:1.19041
# [36]	validation_0-mlogloss:1.19153
# [37]	validation_0-mlogloss:1.19282
# [38]	validation_0-mlogloss:1.19388
# [39]	validation_0-mlogloss:1.19367
# [40]	validation_0-mlogloss:1.19516
# [41]	validation_0-mlogloss:1.19724
# [42]	validation_0-mlogloss:1.19790
# [43]	validation_0-mlogloss:1.19930
# [44]	validation_0-mlogloss:1.20052
# [45]	validation_0-mlogloss:1.20231
# [46]	validation_0-mlogloss:1.20450
# [47]	validation_0-mlogloss:1.20705
# [48]	validation_0-mlogloss:1.20792
# [49]	validation_0-mlogloss:1.21259
# [50]	validation_0-mlogloss:1.21501
# [51]	validation_0-mlogloss:1.21786
# [52]	validation_0-mlogloss:1.21980
# [53]	validation_0-mlogloss:1.22170
# [54]	validation_0-mlogloss:1.22257
# [55]	validation_0-mlogloss:1.22327
# [56]	validation_0-mlogloss:1.22388
# [57]	validation_0-mlogloss:1.22589
# [58]	validation_0-mlogloss:1.23000
# [59]	validation_0-mlogloss:1.23111
# [60]	validation_0-mlogloss:1.23201
# [61]	validation_0-mlogloss:1.23516
# [62]	validation_0-mlogloss:1.23690
# [63]	validation_0-mlogloss:1.23765
# [64]	validation_0-mlogloss:1.24002
# [65]	validation_0-mlogloss:1.24198
# [66]	validation_0-mlogloss:1.24337
# [67]	validation_0-mlogloss:1.24531
# [68]	validation_0-mlogloss:1.24716
# [69]	validation_0-mlogloss:1.24821
# [70]	validation_0-mlogloss:1.25083
# [71]	validation_0-mlogloss:1.25453
# [72]	validation_0-mlogloss:1.25675
# [73]	validation_0-mlogloss:1.25740
# [74]	validation_0-mlogloss:1.25996
# [75]	validation_0-mlogloss:1.26138
# [76]	validation_0-mlogloss:1.26246
# [77]	validation_0-mlogloss:1.26513
# [78]	validation_0-mlogloss:1.26628
# [79]	validation_0-mlogloss:1.26759
# [80]	validation_0-mlogloss:1.27041
# [81]	validation_0-mlogloss:1.27170
# [82]	validation_0-mlogloss:1.27304
# [83]	validation_0-mlogloss:1.27580
# [84]	validation_0-mlogloss:1.27929
# [85]	validation_0-mlogloss:1.28231
# [86]	validation_0-mlogloss:1.28373
# [87]	validation_0-mlogloss:1.28531
# [88]	validation_0-mlogloss:1.28741
# [89]	validation_0-mlogloss:1.29095
# [90]	validation_0-mlogloss:1.29165
# [91]	validation_0-mlogloss:1.29346
# [92]	validation_0-mlogloss:1.29561
# [93]	validation_0-mlogloss:1.29776
# [94]	validation_0-mlogloss:1.30047
# [95]	validation_0-mlogloss:1.30330
# [96]	validation_0-mlogloss:1.30431
# [97]	validation_0-mlogloss:1.30526
# [98]	validation_0-mlogloss:1.30637
# [99]	validation_0-mlogloss:1.30678
# acc: 0.432648401826484

# %% [markdown]
# ## Feature selection

# %%
N = 50

importance = model.feature_importances_
feature_importance = pd.DataFrame({'feature': x_train.columns, 'importance': importance})
feature_importance = feature_importance.sort_values('importance', ascending=False)

selected_features = feature_importance['feature'][:N].tolist()
selected_features
# Out:
# ['long_liquidations_usd_rolling_mean_6',
#  'sell_volume_rolling_mean_5',
#  'volume_diffg_rolling_mean_2',
#  'buy_volume_rolling_mean_6',
#  'open_interest_rolling_mean_6',
#  'liquidation_usd_diff_rolling_mean_2',
#  'open_interest_rolling_mean_3',
#  'open_interest_rolling_mean_5',
#  'open_interest_rolling_mean_7',
#  'liquidation_usd_diffg_rolling_std_2',
#  'liquidation_usd_diff_rolling_mean_7',
#  'sell_volume_rolling_mean_3',
#  'sell_volume',
#  'liquidation_usd_diffg_rolling_mean_10',
#  'sell_volume_rolling_mean_2',
#  'open_interest_rolling_mean_9',
#  'open_interest_rolling_mean_8',
#  'long_liquidations_rolling_std_7',
#  'coinbase_premium_index_rolling_mean_9',
#  'sell_ratio_rolling_mean_5',
#  'short_liquidations_usd_rolling_mean_8',
#  'coinbase_premium_index_rolling_mean_4',
#  'liquidation_diffg_rolling_mean_2',
#  'liquidation_usd_diffg_rolling_std_7',
#  'liquidation_usd_diffg_rolling_std_8',
#  'sell_volume_rolling_mean_8',
#  'buy_volume',
#  'coinbase_premium_index_rolling_mean_2',
#  'open_interest_rolling_mean_10',
#  'coinbase_premium_gap_rolling_mean_9',
#  'liquidation_usd_diffg_rolling_mean_9',
#  'long_liquidations_usd_rolling_std_8',
#  'long_liquidations_usd_rolling_mean_7',
#  'sell_ratio_rolling_mean_8',
#  'buy_volume_rolling_mean_2',
#  'coinbase_premium_index_rolling_mean_8',
#  'buy_volume_rolling_mean_3',
#  'volume_diffg_rolling_std_6',
#  'buy_volume_rolling_mean_4',
#  'coinbase_premium_gap_rolling_mean_6',
#  'long_liquidations_rolling_mean_10',
#  'liquidation_usd_diff',
#  'buy_sell_ratio_rolling_mean_7',
#  'short_liquidations_usd_rolling_mean_9',
#  'open_interest_shift_10',
#  'short_liquidations_usd_rolling_mean_5',
#  'sell_ratio_rolling_mean_6',
#  'short_liquidations_usd_rolling_std_2',
#  'open_interest_rolling_mean_2',
#  'funding_rates_rolling_mean_5']

# %%
# selected features
train_df = train_df[['ID', 'target']+selected_features]

y = train_df['target']    # fetures
x = train_df.drop(['ID', 'target'], axis=1)    # target

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)

# Train
model = XGBClassifier(
    eval_metric='mlogloss',
    random_state=42
)
model = model.fit(
            x_train, y_train, 
            eval_set=[(x_val, y_val)]
            )

# Val
y_pred = model.predict(x_val)

accuracy = accuracy_score(y_val, y_pred)
print(f"acc: {accuracy}")
# Out:
# (7008, 50) (7008,)
# (1752, 50) (1752,)
# [0]	validation_0-mlogloss:1.29939
# [1]	validation_0-mlogloss:1.24500
# [2]	validation_0-mlogloss:1.20843
# [3]	validation_0-mlogloss:1.18553
# [4]	validation_0-mlogloss:1.17019
# [5]	validation_0-mlogloss:1.15747
# [6]	validation_0-mlogloss:1.15012
# [7]	validation_0-mlogloss:1.14687
# [8]	validation_0-mlogloss:1.14561
# [9]	validation_0-mlogloss:1.14412
# [10]	validation_0-mlogloss:1.14355
# [11]	validation_0-mlogloss:1.14502
# [12]	validation_0-mlogloss:1.14672
# [13]	validation_0-mlogloss:1.14833
# [14]	validation_0-mlogloss:1.14974
# [15]	validation_0-mlogloss:1.15015
# [16]	validation_0-mlogloss:1.15233
# [17]	validation_0-mlogloss:1.15398
# [18]	validation_0-mlogloss:1.15542
# [19]	validation_0-mlogloss:1.15745
# [20]	validation_0-mlogloss:1.15997
# [21]	validation_0-mlogloss:1.16159
# [22]	validation_0-mlogloss:1.16318
# [23]	validation_0-mlogloss:1.16548
# [24]	validation_0-mlogloss:1.16822
# [25]	validation_0-mlogloss:1.16964
# [26]	validation_0-mlogloss:1.16979
# [27]	validation_0-mlogloss:1.17011
# [28]	validation_0-mlogloss:1.17077
# [29]	validation_0-mlogloss:1.17180
# [30]	validation_0-mlogloss:1.17410
# [31]	validation_0-mlogloss:1.17484
# [32]	validation_0-mlogloss:1.17648
# [33]	validation_0-mlogloss:1.17509
# [34]	validation_0-mlogloss:1.17564
# [35]	validation_0-mlogloss:1.17591
# [36]	validation_0-mlogloss:1.17815
# [37]	validation_0-mlogloss:1.17859
# [38]	validation_0-mlogloss:1.17899
# [39]	validation_0-mlogloss:1.18089
# [40]	validation_0-mlogloss:1.18332
# [41]	validation_0-mlogloss:1.18482
# [42]	validation_0-mlogloss:1.18604
# [43]	validation_0-mlogloss:1.18539
# [44]	validation_0-mlogloss:1.18628
# [45]	validation_0-mlogloss:1.18750
# [46]	validation_0-mlogloss:1.18863
# [47]	validation_0-mlogloss:1.18981
# [48]	validation_0-mlogloss:1.19148
# [49]	validation_0-mlogloss:1.19329
# [50]	validation_0-mlogloss:1.19521
# [51]	validation_0-mlogloss:1.19663
# [52]	validation_0-mlogloss:1.19870
# [53]	validation_0-mlogloss:1.20180
# [54]	validation_0-mlogloss:1.20102
# [55]	validation_0-mlogloss:1.20229
# [56]	validation_0-mlogloss:1.20482
# [57]	validation_0-mlogloss:1.20793
# [58]	validation_0-mlogloss:1.21049
# [59]	validation_0-mlogloss:1.21441
# [60]	validation_0-mlogloss:1.21585
# [61]	validation_0-mlogloss:1.21685
# [62]	validation_0-mlogloss:1.21875
# [63]	validation_0-mlogloss:1.22059
# [64]	validation_0-mlogloss:1.22154
# [65]	validation_0-mlogloss:1.22304
# [66]	validation_0-mlogloss:1.22336
# [67]	validation_0-mlogloss:1.22585
# [68]	validation_0-mlogloss:1.22946
# [69]	validation_0-mlogloss:1.23045
# [70]	validation_0-mlogloss:1.23229
# [71]	validation_0-mlogloss:1.23421
# [72]	validation_0-mlogloss:1.23623
# [73]	validation_0-mlogloss:1.23780
# [74]	validation_0-mlogloss:1.24047
# [75]	validation_0-mlogloss:1.24271
# [76]	validation_0-mlogloss:1.24318
# [77]	validation_0-mlogloss:1.24353
# [78]	validation_0-mlogloss:1.24417
# [79]	validation_0-mlogloss:1.24608
# [80]	validation_0-mlogloss:1.24699
# [81]	validation_0-mlogloss:1.24859
# [82]	validation_0-mlogloss:1.24977
# [83]	validation_0-mlogloss:1.25075
# [84]	validation_0-mlogloss:1.25156
# [85]	validation_0-mlogloss:1.25207
# [86]	validation_0-mlogloss:1.25319
# [87]	validation_0-mlogloss:1.25517
# [88]	validation_0-mlogloss:1.25676
# [89]	validation_0-mlogloss:1.25741
# [90]	validation_0-mlogloss:1.25892
# [91]	validation_0-mlogloss:1.26185
# [92]	validation_0-mlogloss:1.26258
# [93]	validation_0-mlogloss:1.26423
# [94]	validation_0-mlogloss:1.26574
# [95]	validation_0-mlogloss:1.26709
# [96]	validation_0-mlogloss:1.26945
# [97]	validation_0-mlogloss:1.27042
# [98]	validation_0-mlogloss:1.27130
# [99]	validation_0-mlogloss:1.27288
# acc: 0.4269406392694064

# %% [markdown]
# ## Predict

# %%
# selected features
test_df = test_df[['ID', 'target']+selected_features]

test_data = test_df.drop(["target", "ID"], axis=1)

y_test_pred = model.predict(test_data)

submission_df = pd.read_csv(f"{dir_path}/test.csv")
submission_df = submission_df.assign(target=y_test_pred)
submission_df.to_csv("output.csv", index=False)

print(submission_df.target.value_counts())
submission_df
# Out:
# target
# 2    1634
# 1     926
# 0     181
# 3      51
# Name: count, dtype: int64
#                        ID  target
# 0     2024-01-01 00:00:00       2
# 1     2024-01-01 01:00:00       2
# 2     2024-01-01 02:00:00       1
# 3     2024-01-01 03:00:00       2
# 4     2024-01-01 04:00:00       2
# ...                   ...     ...
# 2787  2024-04-26 03:00:00       2
# 2788  2024-04-26 04:00:00       1
# 2789  2024-04-26 05:00:00       2
# 2790  2024-04-26 06:00:00       2
# 2791  2024-04-26 07:00:00       2
#
# [2792 rows x 2 columns]
